# %%
from sklearn.datasets import load_boston # import banco de dados

# %%
from sklearn import datasets # biblioteca dataset

# %%
import pandas as pd # biblioteca Pandas

# %%
dados = load_boston()# dados total
dataset = pd.DataFrame(dados.data,columns=dados.feature_names) # conjunto de dados
dataset['Media'] = pd.Series(dados.target)
dataset.head() # primeiros dados
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Media
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
dataset.tail()# ultimos dados
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Media
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9

# %%
dataset.shape # linhas e colunas
# Out:
# (506, 14)

# %%
dados.feature_names # Atributos
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
dados.target # dados do banco
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
#Preparando x e y no pandas
# criando lista de atributos
# Cabeçalho - dataset
feature_cols = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT']

X = dataset[feature_cols]

# print the first 5 rows
print('Primeiras linhas do cabeçalho:\n')
X.head()
# Out:
# Primeiras linhas do cabeçalho:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
# Tipos de dados X y
print('\nTipos, linhas e colunas:\n')
print(type(X))
print(X.shape)
# Out:
# Tipos, linhas e colunas:
#
# <class 'pandas.core.frame.DataFrame'>
# (506, 13)

# %%
print('\nVALOR MEDIO:\n')
y = dataset.Media
y.head()
# Out:
# VALOR MEDIO:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: Media, dtype: float64

# %%
# importando seaborn
import seaborn as sns
# allow plots to appear within the notebook
# %matplotlib inline

# %%
sns.pairplot(dataset, x_vars=['CRIM','ZN','INDUS'], y_vars='Media',size=7, aspect=0.7, kind='reg')
sns.pairplot(dataset, x_vars=['CHAS','NOX','RM'], y_vars='Media',size=7, aspect=0.7, kind='reg')
sns.pairplot(dataset, x_vars=['AGE','DIS','RAD'], y_vars='Media',size=7, aspect=0.7, kind='reg')
sns.pairplot(dataset, x_vars=['TAX','PTRATIO','B','LSTAT'], y_vars='Media',size=6, aspect=0.7, kind='reg')
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# Divisão de X e y em conjuntos de treinamento e testes

# %%
print('\ndivisão padrão é 75% para treinamento e 25% para teste:\n')
# Out:
# divisão padrão é 75% para treinamento e 25% para teste:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Treino 75% e teste 25%

# %%
print(X_train.shape,' - treino x')
print(y_train.shape, '- treino y')
print(X_test.shape, '- teste x')
print(y_test.shape, '- teste y')
# Out:
# (379, 13)  - treino x
# (379,) - treino y
# (127, 13) - teste x
# (127,) - teste y

# %%
# faz previsões no conjunto de testes

# %%
# define valores de resposta verdadeiras e previstas

# %%
true = [100, 50, 30, 20]# teste
pred = [90, 50, 50, 30]# treino
#[10,0,20,10] - variação teste e treino

# %%
#Calculando margens de erros

# %%
#intercepto e coeficientes

# %%
#Linear regression in scikit-learn

# %%
# import model
from sklearn.linear_model import LinearRegression

# instantiate
linreg = LinearRegression()

# fit the model to the training data (learn the coefficients)
linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred = linreg.predict(X_test)

# %%
# Interpretação dos coeficientes do modelo
# imprima o intercepto e coeficientes

# %%
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# 45.19251538838445
# [-1.14428903e-01  5.71299780e-02  3.83002824e-02  2.42854641e+00
#  -2.12326236e+01  2.87723416e+00  6.91118094e-03 -1.47158266e+00
#   3.05784197e-01 -1.06750361e-02 -9.96138270e-01  6.27746234e-03
#  -5.57414427e-01]

# %%
# Método MAE

# %%
print((10 + 0 + 20 + 10)/4.)# média da variação 

# calculate MAE using scikit-learn
from sklearn import metrics
print(metrics.mean_absolute_error(y_test, y_pred))
# Out:
# 10.0
# 3.574868126127553

# %%
# Método MSE

# %%
# calculate MSE by hand
print((10**2 + 0**2 + 20**2 + 10**2)/4.)# média elevado a Potência de 2

# calculate MSE using scikit-learn
print(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 150.0
# 21.89776539604953

# %%
# Método RMSE

# %%
# calculate RMSE by hand
import numpy as np
print(np.sqrt((10**2 + 0**2 + 20**2 + 10**2)/4.))# raiz da média elevado a Potência de 2

# calculate RMSE using scikit-learn
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 12.24744871391589
# 4.679504823808768

# %%
# nomes de atributos com os coeficientes

# %%
list(zip(feature_cols, linreg.coef_))
# Out:
# [('CRIM', -0.11442890306628235),
#  ('ZN', 0.05712997804798539),
#  ('INDUS', 0.03830028239368884),
#  ('CHAS', 2.4285464082017794),
#  ('NOX', -21.232623560528985),
#  ('RM', 2.877234156006159),
#  ('AGE', 0.0069111809363668515),
#  ('DIS', -1.4715826611839502),
#  ('RAD', 0.3057841971271403),
#  ('TAX', -0.010675036077891945),
#  ('PTRATIO', -0.9961382695506908),
#  ('B', 0.00627746234129183),
#  ('LSTAT', -0.5574144267110019)]

# %%
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))# Resposta do modelo RMSE
# Out:
# 4.679504823808768

# %%
# Minerando dadso RMSE

# %%
# criar uma lista Python de nomes de atributos

# %%
# NOX retirado - taxa de erro menor, menor relevancia - realizar testes
feature_cols= ['CRIM','ZN','INDUS','CHAS','RM','AGE','DIS','RAD','TAX','B','PTRATIO','LSTAT']

# %%
# usando a lista para selecionar um subconjunto do DataFrame original

# %%
X = dataset[feature_cols]

# %%
# dividindo em conjuntos de treinamento e testes

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# encaixando o modelo nos dados de treinamento (aprenda os coeficientes)

# %%
linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# fazendo previsões no conjunto de testes

# %%
y_pred = linreg.predict(X_test)

# %%
# computar o RMSE de previsões

# %%
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred))) # comparar com outros metodos - realizar testes
# Out:
# 4.6056965712256375
